# %%
import re
import pandas as pd

# %%
# regex_text

filename = 'EngMgt.txt'

with open(filename, 'r') as f:
        lines = f.readlines()

course_data = {
        'course_number': [],
        'course_name': [],
        'class': [],
        'section_info': [],
        'occurrences': [],
        'arrangements': [],
        'room': [],
        'instructors': []
}

for i, line in enumerate(lines):
    if re.search(r"([A-Z]+(?:\s+[A-Z]+)?\s+\d+)\s*-\s*(.*)", line) and "-" in line and 'Collapsible' not in line:

        # pulling course name & number
        course_num, course_title = line.split(" - ", 1)
        course_data['course_number'].append(course_num) # pulls course name
        course_data['course_name'].append(course_title)

        # The rest
        course_data['class'].append(lines[i + 2]) # course
        course_data['section_info'].append(lines[i + 3])
        course_data['occurrences'].append(lines[i + 4])
        course_data['arrangements'].append(lines[i + 5])
        course_data['room'].append(lines[i + 6])

        instructor_list = []
        for j in range(i + 7, len(lines)):
            if re.match(r"^[A-Za-z .,'-]+$", lines[j].strip()):
                instructor_list.append(lines[j])
            else:
                if instructor_list:
                    instructor_str = ", ".join(instructor_list)
                    course_data['instructors'].append(", ".join(instructor_list))
                    break

df = pd.DataFrame(course_data)
df.to_csv('course_data.csv', index=False)
display(df)
# Out:
#    course_number                                  course_name    class  \
# 0   ENG MGT 1100  Practical Concepts for Technical Managers\n  70964\n
# 1   ENG MGT 1100  Practical Concepts for Technical Managers\n  70965\n
# 2   ENG MGT 1210  Economic Analysis of Engineering Projects\n  71014\n
# 3   ENG MGT 1210  Economic Analysis of Engineering Projects\n  70957\n
# 4   ENG MGT 2002           Cooperative Engineering Training\n  70372\n
# ..           ...                                          ...      ...
# 75  ENG MGT 6112                   Leadership for Engineers\n  70993\n
# 76  ENG MGT 6211              Advanced Financial Management\n  71113\n
# 77  ENG MGT 6211              Advanced Financial Management\n  71114\n
# 78  ENG MGT 6322         Case Studies in Project Management\n  70931\n
# 79  ENG MGT 6322         Case Studies in Project Management\n  70932\n
#
#    section_info occurrences             arrangements  \
# 0     101-LEC\n   Regular\n               Arranged\n
# 1     102-LEC\n   Regular\n               Arranged\n
# 2     101-LEC\n   Regular\n               Arranged\n
# 3     102-LEC\n   Regular\n  TuTh 12:30PM - 1:20PM\n
# 4     601-IND\n   Regular\n               Arranged\n
# ..          ...         ...                      ...
# 75    102-LEC\n   Regular\n               Arranged\n
# 76    101-LEC\n   Regular\n     Th 4:00PM - 6:30PM\n
# 77    102-LEC\n   Regular\n     Th 4:00PM - 6:30PM\n
# 78    101-LEC\n   Regular\n     We 7:00PM - 9:30PM\n
# 79    102-LEC\n   Regular\n     We 7:00PM - 9:30PM\n
#
#                             room               instructors
# 0                     Internet\n          Kellie Grasman\n
# 1                     Internet\n          Kellie Grasman\n
# 2                     Internet\n  Javier Valentin-Sivico\n
# 3                     Internet\n  Javier Valentin-Sivico\n
# 4                     Internet\n            Joan Schuman\n
# ..                           ...                       ...
# 75                    Internet\n           John Richards\n
# 76  Engineering Manageme 00201\n           Robert Marley\n
# 77                    Internet\n           Robert Marley\n
# 78                    Internet\n           Sheryl Hodges\n
# 79                    Internet\n           Sheryl Hodges\n
#
# [80 rows x 8 columns]
